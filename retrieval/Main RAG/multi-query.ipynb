# %%
! pip install langchain_community tiktoken langchain-openai langchainhub chromadb langchain
# Out:
# Requirement already satisfied: langchain_community in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (0.3.24)
# Requirement already satisfied: tiktoken in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (0.9.0)
# Requirement already satisfied: langchain-openai in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (0.3.16)
# Requirement already satisfied: langchainhub in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (0.1.21)
# Requirement already satisfied: chromadb in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (1.0.9)
# Requirement already satisfied: langchain in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (0.3.25)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.59 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (0.3.59)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (3.10.11)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (2.9.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (0.3.24)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (0.4.0)
# Requirement already satisfied: numpy>=2.1.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (2.2.5)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain) (2.11.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.4.3)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.59->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.59->langchain_community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.59->langchain_community) (4.13.1)
# Requirement already satisfied: jsonpointer>=1.9 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.59->langchain_community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.23.0)
# Requirement already satisfied: anyio in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (4.9.0)
# Requirement already satisfied: certifi in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (1.0.7)
# Requirement already satisfied: idna in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests<3,>=2->langchain_community) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests<3,>=2->langchain_community) (2.3.0)
# Requirement already satisfied: greenlet>=1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.1.0)
# Requirement already satisfied: propcache>=0.2.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.1)
# Requirement already satisfied: regex>=2022.1.18 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: openai<2.0.0,>=1.68.2 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain-openai) (1.70.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (0.9.0)
# Requirement already satisfied: sniffio in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (4.67.1)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchainhub) (2.32.0.20250328)
# Requirement already satisfied: build>=1.0.3 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: fastapi==0.115.9 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (0.115.9)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.2)
# Requirement already satisfied: posthog>=2.4.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (3.23.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (1.33.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (1.33.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (0.54b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (1.33.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (0.15.3)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: rich>=10.11.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from fastapi==0.115.9->chromadb) (0.45.3)
# Requirement already satisfied: pyproject_hooks in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (0.24.0)
# Requirement already satisfied: six>=1.9.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.4)
# Requirement already satisfied: sympy in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: deprecated>=1.2.6 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.6.1)
# Requirement already satisfied: zipp>=3.20 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.2.0->chromadb) (1.17.2)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.69.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.0)
# Requirement already satisfied: opentelemetry-proto==1.33.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.54b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.54b0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.54b0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b0)
# Requirement already satisfied: opentelemetry-util-http==0.54b0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b0)
# Requirement already satisfied: asgiref~=3.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from opentelemetry-instrumentation-asgi==0.54b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tokenizers>=0.13.2->chromadb) (0.31.1)
# Requirement already satisfied: filelock in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.1.0)
# Requirement already satisfied: click>=8.0.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)

# %%
import os
from dotenv import load_dotenv
# Load environment variables from .env file
load_dotenv()

# Access environment variables
tracing_enabled = os.getenv('LANGCHAIN_TRACING_V2')
endpoint = os.getenv('LANGCHAIN_ENDPOINT')
api_key = os.getenv('LANGCHAIN_API_KEY')
gemini_api_key = os.getenv('GEMINI_API_KEY')

# %%
from langchain.prompts import ChatPromptTemplate

# Multi Query: Different Perspectives
template = """You are an AI language model assistant. Your task is to generate five 
different versions of the given user question to retrieve relevant documents from a vector 
database. By generating multiple perspectives on the user question, your goal is to help
the user overcome some of the limitations of the distance-based similarity search. 
Provide these alternative questions separated by newlines. Original question: {question}"""

prompt_perspectives = ChatPromptTemplate.from_template(template)

from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI

generate_queries = (
    prompt_perspectives 
    | ChatOpenAI(temperature=0) 
    | StrOutputParser() 
    | (lambda x: x.split("\n"))
)

# %%
#Get functions from indexing
import import_ipynb
import indexing
retriever = indexing.embed_data_from_pdf("de-an-tuyen-sinh-2024final.pdf")
# Out:
# Requirement already satisfied: langchain_community in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (0.3.24)
# Requirement already satisfied: tiktoken in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (0.9.0)
# Requirement already satisfied: langchain-openai in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (0.3.16)
# Requirement already satisfied: langchainhub in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (0.1.21)
# Requirement already satisfied: chromadb in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (1.0.9)
# Requirement already satisfied: langchain in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (0.3.25)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.59 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (0.3.59)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (3.10.11)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (2.9.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (0.3.24)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (0.4.0)
# Requirement already satisfied: numpy>=2.1.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain_community) (2.2.5)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain) (2.11.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.4.3)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.59->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.59->langchain_community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.59->langchain_community) (4.13.1)
# Requirement already satisfied: jsonpointer>=1.9 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.59->langchain_community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.23.0)
# Requirement already satisfied: anyio in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (4.9.0)
# Requirement already satisfied: certifi in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (1.0.7)
# Requirement already satisfied: idna in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests<3,>=2->langchain_community) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests<3,>=2->langchain_community) (2.3.0)
# Requirement already satisfied: greenlet>=1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.1.0)
# Requirement already satisfied: propcache>=0.2.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.1)
# Requirement already satisfied: regex>=2022.1.18 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: openai<2.0.0,>=1.68.2 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchain-openai) (1.70.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (0.9.0)
# Requirement already satisfied: sniffio in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (4.67.1)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from langchainhub) (2.32.0.20250328)
# Requirement already satisfied: build>=1.0.3 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: fastapi==0.115.9 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (0.115.9)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.2)
# Requirement already satisfied: posthog>=2.4.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (3.23.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (1.33.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (1.33.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (0.54b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (1.33.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (0.15.3)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: rich>=10.11.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from fastapi==0.115.9->chromadb) (0.45.3)
# Requirement already satisfied: pyproject_hooks in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (0.24.0)
# Requirement already satisfied: six>=1.9.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.4)
# Requirement already satisfied: sympy in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: deprecated>=1.2.6 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.6.1)
# Requirement already satisfied: zipp>=3.20 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.2.0->chromadb) (1.17.2)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.69.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.0)
# Requirement already satisfied: opentelemetry-proto==1.33.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.54b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.54b0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.54b0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b0)
# Requirement already satisfied: opentelemetry-util-http==0.54b0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b0)
# Requirement already satisfied: asgiref~=3.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from opentelemetry-instrumentation-asgi==0.54b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tokenizers>=0.13.2->chromadb) (0.31.1)
# Requirement already satisfied: filelock in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.1.0)
# Requirement already satisfied: click>=8.0.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/hoangnam/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# [INFO] Loading PDF document from: de-an-tuyen-sinh-2024final.pdf
# [INFO] Generating embeddings with Gemini...
# [INFO] Storing embeddings in Chroma Vector Store...
# page_content='BỘ GIÁO DỤC VÀ ĐÀO TẠO CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM
# ĐẠI HỌC BÁCH KHOA HÀ NỘI Độc lập - Tự do - Hạnh phúc
# ĐỀ ÁN TUYỂN SINH ĐẠI HỌC NĂM 2024
# (Ban hành kèm theo quyết định số 4688/QĐ-ĐHBK ngày 22/05/2024
# của Giám đốc ĐHBK Hà Nội)
# I. Thông tin chung (tính đến thời điểm xây dựng kế hoạch tuyển sinh)' metadata={'source': 'de-an-tuyen-sinh-2024final.pdf', 'file_path': 'de-an-tuyen-sinh-2024final.pdf', 'page': 0, 'total_pages': 39, 'Author': 'HOANGBD', 'Creator': 'Microsoft® Word for Microsoft 365', 'CreationDate': "D:20240527091605+07'00'", 'ModDate': "D:20240527091605+07'00'", 'Producer': 'Microsoft® Word for Microsoft 365'}
# page_content='1. Tên cơ sở đào tạo: Đại học Bách khoa Hà Nội
# Đại học Bách khoa Hà Nội sử dụng tên giao dịch quốc tế là Hanoi University of
# Science and Technology (viết tắt là HUST).
# 2. Mã trường: BKA
# 3. Địa chỉ các trụ sở (trụ sở chính và phân hiệu): Số 1 Đại Cồ Việt, quận Hai Bà
# Trưng, thành phố Hà Nội.
# 4. Địa chỉ trang thông tin điện tử của Đại học Bách khoa Hà Nội:' metadata={'source': 'de-an-tuyen-sinh-2024final.pdf', 'file_path': 'de-an-tuyen-sinh-2024final.pdf', 'page': 0, 'total_pages': 39, 'Author': 'HOANGBD', 'Creator': 'Microsoft® Word for Microsoft 365', 'CreationDate': "D:20240527091605+07'00'", 'ModDate': "D:20240527091605+07'00'", 'Producer': 'Microsoft® Word for Microsoft 365'}
# page_content='- Trang thông tin chung: https://hust.edu.vn;
# - Trang thông tin tuyển sinh: https://ts-hn.hust.edu.vn;
# 5. Địa chỉ các trang mạng xã hội của cơ sở đào tạo (có thông tin tuyển sinh):
# https://www.facebook.com/tsdhbk
# 6. Số điện thoại liên hệ tuyển sinh: 024.38683408
# 7. Tình hình việc làm của sinh viên sau khi tốt nghiệp
# Đường link công khai việc làm của sinh viên sau khi tốt nghiệp trên trang thông tin' metadata={'source': 'de-an-tuyen-sinh-2024final.pdf', 'file_path': 'de-an-tuyen-sinh-2024final.pdf', 'page': 0, 'total_pages': 39, 'Author': 'HOANGBD', 'Creator': 'Microsoft® Word for Microsoft 365', 'CreationDate': "D:20240527091605+07'00'", 'ModDate': "D:20240527091605+07'00'", 'Producer': 'Microsoft® Word for Microsoft 365'}
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# [INFO] Vectorstore created with collection name: de-an-tuyen-sinh-2024final_4c40
# [INFO] Creating retriever...
# [INFO] PDF embedding and storage complete.
# [INFO] Total Documents Indexed: 194
# [INFO] Index Name: vietnam_university_pdfs
# [INFO] Source: de-an-tuyen-sinh-2024final.pdf
# • de-an-tuyen-sinh-2024final_4c40
# [INFO] Loading PDF document from: de-an-tuyen-sinh-2024final.pdf
# [INFO] Generating embeddings with Gemini...
# [INFO] Storing embeddings in Chroma Vector Store...
# page_content='BỘ GIÁO DỤC VÀ ĐÀO TẠO CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM
# ĐẠI HỌC BÁCH KHOA HÀ NỘI Độc lập - Tự do - Hạnh phúc
# ĐỀ ÁN TUYỂN SINH ĐẠI HỌC NĂM 2024
# (Ban hành kèm theo quyết định số 4688/QĐ-ĐHBK ngày 22/05/2024
# của Giám đốc ĐHBK Hà Nội)
# I. Thông tin chung (tính đến thời điểm xây dựng kế hoạch tuyển sinh)' metadata={'source': 'de-an-tuyen-sinh-2024final.pdf', 'file_path': 'de-an-tuyen-sinh-2024final.pdf', 'page': 0, 'total_pages': 39, 'Author': 'HOANGBD', 'Creator': 'Microsoft® Word for Microsoft 365', 'CreationDate': "D:20240527091605+07'00'", 'ModDate': "D:20240527091605+07'00'", 'Producer': 'Microsoft® Word for Microsoft 365'}
# page_content='1. Tên cơ sở đào tạo: Đại học Bách khoa Hà Nội
# Đại học Bách khoa Hà Nội sử dụng tên giao dịch quốc tế là Hanoi University of
# Science and Technology (viết tắt là HUST).
# 2. Mã trường: BKA
# 3. Địa chỉ các trụ sở (trụ sở chính và phân hiệu): Số 1 Đại Cồ Việt, quận Hai Bà
# Trưng, thành phố Hà Nội.
# 4. Địa chỉ trang thông tin điện tử của Đại học Bách khoa Hà Nội:' metadata={'source': 'de-an-tuyen-sinh-2024final.pdf', 'file_path': 'de-an-tuyen-sinh-2024final.pdf', 'page': 0, 'total_pages': 39, 'Author': 'HOANGBD', 'Creator': 'Microsoft® Word for Microsoft 365', 'CreationDate': "D:20240527091605+07'00'", 'ModDate': "D:20240527091605+07'00'", 'Producer': 'Microsoft® Word for Microsoft 365'}
# page_content='- Trang thông tin chung: https://hust.edu.vn;
# - Trang thông tin tuyển sinh: https://ts-hn.hust.edu.vn;
# 5. Địa chỉ các trang mạng xã hội của cơ sở đào tạo (có thông tin tuyển sinh):
# https://www.facebook.com/tsdhbk
# 6. Số điện thoại liên hệ tuyển sinh: 024.38683408
# 7. Tình hình việc làm của sinh viên sau khi tốt nghiệp
# Đường link công khai việc làm của sinh viên sau khi tốt nghiệp trên trang thông tin' metadata={'source': 'de-an-tuyen-sinh-2024final.pdf', 'file_path': 'de-an-tuyen-sinh-2024final.pdf', 'page': 0, 'total_pages': 39, 'Author': 'HOANGBD', 'Creator': 'Microsoft® Word for Microsoft 365', 'CreationDate': "D:20240527091605+07'00'", 'ModDate': "D:20240527091605+07'00'", 'Producer': 'Microsoft® Word for Microsoft 365'}
# [INFO] Vectorstore created with collection name: de-an-tuyen-sinh-2024final_e731
# [INFO] Creating retriever...
# [INFO] PDF embedding and storage complete.
# [INFO] Total Documents Indexed: 194
# [INFO] Index Name: vietnam_university_pdfs
# [INFO] Source: de-an-tuyen-sinh-2024final.pdf

# %%
from langchain.load import dumps, loads

def get_unique_union(documents: list[list]):
    """ Unique union of retrieved docs """
    # Flatten list of lists, and convert each Document to string
    flattened_docs = [dumps(doc) for sublist in documents for doc in sublist]
    # Get unique documents
    unique_docs = list(set(flattened_docs))
    # Return
    return [loads(doc) for doc in unique_docs]

# Retrieve
question = "Xét giải học sinh giỏi quốc gia như nào?"
retrieval_chain = generate_queries | retriever.map() | get_unique_union
docs = retrieval_chain.invoke({"question":question})
len(docs)
# Out:
# 20

# %%
from operator import itemgetter
from langchain_openai import ChatOpenAI
from langchain_core.runnables import RunnablePassthrough

# RAG
template = """Answer the following question based on this context:

{context}

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)

llm = ChatOpenAI(temperature=0)

final_rag_chain = (
    {"context": retrieval_chain, 
     "question": itemgetter("question")} 
    | prompt
    | llm
    | StrOutputParser()
)

final_rag_chain.invoke({"question":question})
# Out:
# 'Để xét giải học sinh giỏi quốc gia, thí sinh cần đạt giải Nhất, Nhì cấp Tỉnh/Thành phố trở lên trong cuộc thi KHKT do Sở GDĐT, Bộ GDĐT chủ trì tổ chức để lựa chọn đi dự thi ViSEF và ISEF. Thí sinh cũng có thể được chọn tham dự cuộc thi Đường lên đỉnh Olympia do Đài Truyền hình Việt Nam chủ trì tổ chức từ vòng thi tháng trở lên.'
